# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ayush\Downloads\placement.csv")
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df = df.rename(columns={'placement_exam_marks': 'score'})
df
# Out:
#      cgpa  score  placed
# 0    7.19   26.0       1
# 1    7.46   38.0       1
# 2    7.54   40.0       1
# 3    6.42    8.0       1
# 4    7.23   17.0       0
# ..    ...    ...     ...
# 995  8.87   44.0       1
# 996  9.12   65.0       1
# 997  4.89   34.0       0
# 998  8.62   46.0       1
# 999  4.90   10.0       1
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='cgpa',y='score',data=df,hue="placed")
plt.legend(loc=1)
plt.show()

# %%
x = df.iloc[:,:-1]
x
# Out:
#      cgpa  score
# 0    7.19   26.0
# 1    7.46   38.0
# 2    7.54   40.0
# 3    6.42    8.0
# 4    7.23   17.0
# ..    ...    ...
# 995  8.87   44.0
# 996  9.12   65.0
# 997  4.89   34.0
# 998  8.62   46.0
# 999  4.90   10.0
#
# [1000 rows x 2 columns]

# %%
x.ndim
# Out:
# 2

# %%
y = df['placed']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    1
# Name: placed, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.515

# %%
lr.predict([[4.89,34.0]])
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
lr.coef_
# Out:
# array([[ 0.01444006, -0.00374614]])

# %%
lr.intercept_
# Out:
# array([0.00179645])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(x)
x = pd.DataFrame(pf.transform(x))

# %%
x
# Out:
#        0     1     2        3       4       5
# 0    1.0  7.19  26.0  51.6961  186.94   676.0
# 1    1.0  7.46  38.0  55.6516  283.48  1444.0
# 2    1.0  7.54  40.0  56.8516  301.60  1600.0
# 3    1.0  6.42   8.0  41.2164   51.36    64.0
# 4    1.0  7.23  17.0  52.2729  122.91   289.0
# ..   ...   ...   ...      ...     ...     ...
# 995  1.0  8.87  44.0  78.6769  390.28  1936.0
# 996  1.0  9.12  65.0  83.1744  592.80  4225.0
# 997  1.0  4.89  34.0  23.9121  166.26  1156.0
# 998  1.0  8.62  46.0  74.3044  396.52  2116.0
# 999  1.0  4.90  10.0  24.0100   49.00   100.0
#
# [1000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 51.0
